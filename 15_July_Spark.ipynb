# %% [markdown]
# 1. Working with RDDs:
#    a) Write a Python program to create an RDD from a local data source.
#    b) Implement transformations and actions on the RDD to perform data processing tasks.
#    c) Analyze and manipulate data using RDD operations such as map, filter, reduce, or aggregate.

# %% [raw]
# from pyspark import SparkContext
#
# # Create a SparkContext
# sc = SparkContext("local", "RDD Example")
#
# # Part a) Create an RDD from a local data source
# data = [1, 2, 3, 4, 5]
# rdd = sc.parallelize(data)
#
# # Part b) Implement transformations and actions on the RDD
# # Transformation: Map - Square each element
# squared_rdd = rdd.map(lambda x: x ** 2)
#
# # Transformation: Filter - Keep only even numbers
# even_rdd = squared_rdd.filter(lambda x: x % 2 == 0)
#
# # Action: Reduce - Sum all the elements
# sum_result = even_rdd.reduce(lambda x, y: x + y)
#
# # Part c) Analyze and manipulate data using RDD operations
# # Count the number of elements in the RDD
# count = rdd.count()
#
# # Calculate the average of the elements in the RDD
# average = rdd.reduce(lambda x, y: x + y) / count
#
# # Print the results
# print("Original RDD:", rdd.collect())
# print("Squared RDD:", squared_rdd.collect())
# print("Even Numbers RDD:", even_rdd.collect())
# print("Sum of Even Numbers:", sum_result)
# print("Count:", count)
# print("Average:", average)
#
# # Stop the SparkContext
# sc.stop()

# %% [markdown]
# 2. Spark DataFrame Operations:
#    a) Write a Python program to load a CSV file into a Spark DataFrame.
#    b)Perform common DataFrame operations such as filtering, grouping, or joining.
#    c) Apply Spark SQL queries on the DataFrame to extract insights from the data.

# %% [raw]
# from pyspark.sql import SparkSession
#
# # Create a SparkSession
# spark = SparkSession.builder.appName("DataFrame Example").getOrCreate()
#
# # Part a) Load a CSV file into a Spark DataFrame
# csv_file_path = "/path/to/csv/file.csv"
# df = spark.read.csv(csv_file_path, header=True, inferSchema=True)
#
# # Part b) Perform common DataFrame operations
# # Filter: Keep rows where age is greater than 30
# filtered_df = df.filter(df["age"] > 30)
#
# # GroupBy and Aggregation: Calculate the average salary by gender
# avg_salary_by_gender = df.groupBy("gender").avg("salary")
#
# # Join: Join with another DataFrame based on a common column
# other_df = spark.read.csv("/path/to/other/file.csv", header=True, inferSchema=True)
# joined_df = df.join(other_df, on="common_column", how="inner")
#
# # Part c) Apply Spark SQL queries on the DataFrame
# # Register the DataFrame as a temporary table
# df.createOrReplaceTempView("people")
#
# # Run a SQL query to extract insights from the data
# query = """
#     SELECT gender, AVG(salary) AS average_salary
#     FROM people
#     WHERE age > 30
#     GROUP BY gender
# """
# result = spark.sql(query)
#
# # Show the results
# result.show()
#
# # Stop the SparkSession
# spark.stop()

# %% [markdown]
# 3. Spark Streaming:
#   a) Write a Python program to create a Spark Streaming application.
#    b) Configure the application to consume data from a streaming source (e.g., Kafka or a socket).
#    c) Implement streaming transformations and actions to process and analyze the incoming data stream.

# %% [raw]
# from pyspark.streaming import StreamingContext
# from pyspark.streaming.kafka import KafkaUtils
#
# # Create a StreamingContext with a batch interval of 1 second
# spark_context = SparkContext(appName="Streaming Example")
# streaming_context = StreamingContext(spark_context, 1)
#
# # Part a) Create a Spark Streaming application
# # Define the function to process each batch of data
# def process_batch(batch):
#     # Process the data here
#     # Example: Count the number of lines in the batch
#     line_count = batch.count()
#     print("Lines in the batch:", line_count)
#
# # Part b) Configure the application to consume data from a streaming source
# # Create a DStream by connecting to a socket
# socket_stream = streaming_context.socketTextStream("localhost", 9999)
#
# # Part c) Implement streaming transformations and actions
# # Transformation: Split each line into words
# words = socket_stream.flatMap(lambda line: line.split(" "))
#
# # Action: Count the occurrences of each word
# word_counts = words.countByValue()
#
# # Print the word counts in each batch
# word_counts.pprint()
#
# # Apply the processing function to each batch of data
# socket_stream.foreachRDD(process_batch)
#
# # Start the streaming context
# streaming_context.start()
#
# # Wait for the streaming to finish
# streaming_context.awaitTermination()

# %% [markdown]
# 4. Spark SQL and Data Source Integration:
#    a) Write a Python program to connect Spark with a relational database (e.g., MySQL, PostgreSQL).
#    b)Perform SQL operations on the data stored in the database using Spark SQL.
#    c) Explore the integration capabilities of Spark with other data sources, such as Hadoop Distributed File System (HDFS) or Amazon S3.

# %% [raw]
# from pyspark.sql import SparkSession
#
# # Part a) Connect Spark with a relational database (MySQL)
# # Create a SparkSession
# spark = SparkSession.builder \
#     .appName("Spark SQL Example") \
#     .config("spark.jars.packages", "mysql:mysql-connector-java:8.0.26") \
#     .getOrCreate()
#
# # Configure the MySQL connection properties
# mysql_host = "localhost"
# mysql_port = "3306"
# mysql_database = "your_database_name"
# mysql_table = "your_table_name"
# mysql_username = "your_username"
# mysql_password = "your_password"
#
# # Create a JDBC URL for MySQL connection
# jdbc_url = f"jdbc:mysql://{mysql_host}:{mysql_port}/{mysql_database}"
#
# # Read data from the MySQL table into a DataFrame
# df = spark.read \
#     .format("jdbc") \
#     .option("url", jdbc_url) \
#     .option("dbtable", mysql_table) \
#     .option("user", mysql_username) \
#     .option("password", mysql_password) \
#     .load()
#
# # Part b) Perform SQL operations on the data stored in the database using Spark SQL
# # Register the DataFrame as a temporary view
# df.createOrReplaceTempView("my_table")
#
# # Run SQL queries on the DataFrame
# result = spark.sql("SELECT * FROM my_table WHERE age > 30")
#
# # Show the results
# result.show()
#
# # Part c) Explore integration capabilities of Spark with other data sources (HDFS)
# # Read data from a file stored in HDFS into a DataFrame
# hdfs_file_path = "hdfs://localhost:9000/path/to/file.csv"
# df_hdfs = spark.read.csv(hdfs_file_path, header=True, inferSchema=True)
#
# # Perform operations on the DataFrame
# # ...
#
# # Stop the SparkSession
# spark.stop()
